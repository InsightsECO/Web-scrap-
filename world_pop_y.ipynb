# %% [markdown]
#   # <h1>                          WEB SCRAPING USING PYTHON

# %% [markdown]
#  we will hit the following target to achieve our goal

# %% [markdown]
# • Data extraction from the web using Python's Beautiful Soup module
#
# • Data manipulation and cleaning using Python's Pandas library

# %% [markdown]
# 1) importing the required libraries

# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# 2) we are extracting the data from worldometer(world-population-by-year)

# %%
# requests module helps to fetch the website
url = "https://www.worldometers.info/world-population/world-population-by-year/"
response = requests.get(url)
data = response.text

# %% [markdown]
# <h4> Data extraction from the web using Python's Beautiful Soup module

# %%
# beautiful soup helps to fetch html tags, that can helpful to exract data from those tags
soup = BeautifulSoup(data, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
title = soup.title
title.string
# Out:
# 'World Population by Year - Worldometer'

# %%
# Print out the text
text = soup.get_text()
#print(soup.text)

# %%
# fetch all 'a' tags from html code 
soup.find_all('a')
# Out:
# [<a class="navbar-brand" href="/"><img border="0" src="/img/worldometers-logo.gif" title="Worldometer"/></a>,
#  <a href="/coronavirus/"><span style="color:#FF9900; font-weight:bold">Coronavirus</span></a>,
#  <a href="/population/">Population</a>,
#  <a href="/">W</a>,
#  <a href="/population/">Population</a>,
#  <a href="/population/world/">World</a>,
#  <a href="/">www.Worldometers.info</a>,
#  <a href="https://esa.un.org/unpd/wpp/">World Population Prospects: The 2019 Revision</a>,
#  <a href="/"><img border="0" class="img-footer" src="/img/worldometers-logo-footer.png"/></a>,
#  <a href="/about/">about</a>,
#  <a href="/faq/">faq</a>,
#  <a href="/languages/">languages</a>,
#  <a href="/contact/">contact</a>,
#  <a data-placement="bottom" data-toggle="tooltip" href="/newsletter-subscribe/" title="Newsletter"><i class="fa fa-bullhorn fa-round"></i></a>,
#  <a href="https://twitter.com/Worldometers"><i class="fa fa-twitter fa-round"></i></a>,
#  <a href="https://www.facebook.com/Worldometers.info"><i class="fa fa-facebook fa-round"></i></a>,
#  <a href="/disclaimer/">Disclaimer &amp; Privacy Policy</a>]

# %%
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# /
# /coronavirus/
# /population/
# /
# /population/
# /population/world/
# /
# https://esa.un.org/unpd/wpp/
# /
# /about/
# /faq/
# /languages/
# /contact/
# /newsletter-subscribe/
# https://twitter.com/Worldometers
# https://www.facebook.com/Worldometers.info
# /disclaimer/

# %%
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr> <th>Year</th><th><div align="right">World Population</div></th><th style="text-align:center">Yearly<br/>Change</th><th style="text-align:center">Net<br/>Change</th><th style="text-align:center">Density<br/>(P/Km²)</th><th style="text-align:center">Urban<br/>Pop</th><th style="text-align:center">Urban<br/>Pop %</th> </tr>, <tr> <td>2020</td> <td style="font-weight: bold; text-align :right">7,794,798,739</td> <td style="text-align:right">1.05 %</td><td style="text-align:right">81,330,639</td><td style="text-align:right">52</td> <td style="text-align:right">4,378,993,944</td> <td style="text-align:right">56 %</td> </tr>, <tr> <td>2019</td> <td style="font-weight: bold; text-align:right">7,713,468,100</td> <td style="text-align:right">1.08 %</td><td style="text-align:right">82,377,060</td><td style="text-align:right">52</td> <td style="text-align:right">4,299,438,618</td> <td style="text-align:right">56 %</td> </tr>, <tr> <td>2018</td> <td style="font-weight: bold; text-align:right">7,631,091,040</td> <td style="text-align:right">1.10 %</td><td style="text-align:right">83,232,115</td><td style="text-align:right">51</td> <td style="text-align:right">4,219,817,318</td> <td style="text-align:right">55 %</td> </tr>, <tr> <td>2017</td> <td style="font-weight: bold; text-align:right">7,547,858,925</td> <td style="text-align:right">1.12 %</td><td style="text-align:right">83,836,876</td><td style="text-align:right">51</td> <td style="text-align:right">4,140,188,594</td> <td style="text-align:right">55 %</td> </tr>, <tr> <td>2016</td> <td style="font-weight: bold; text-align:right">7,464,022,049</td> <td style="text-align:right">1.14 %</td> <td style="text-align:right">84,224,910</td> <td style="text-align:right">50</td> <td style="text-align:right">4,060,652,683</td> <td style="text-align:right">54 %</td> </tr>, <tr> <td>2015</td> <td style="font-weight: bold; text-align:right">7,379,797,139</td> <td style="text-align:right">1.16 %</td> <td style="text-align:right">84,506,374</td><td style="text-align:right">50</td> <td style="text-align:right">3,981,497,663</td> <td style="text-align:right">54 %</td> </tr>, <tr> <td>2014</td> <td style="font-weight: bold; text-align:right">7,295,290,765</td> <td style="text-align:right">1.17 %</td> <td style="text-align:right">84,708,789</td> <td style="text-align:right">49</td> <td style="text-align:right">3,902,831,934</td> <td style="text-align:right">53 %</td> </tr>, <tr> <td>2013</td> <td style="font-weight: bold; text-align:right">7,210,581,976</td> <td style="text-align:right">1.19 %</td> <td style="text-align:right">84,753,917</td> <td style="text-align:right">48</td> <td style="text-align:right">3,824,990,329</td> <td style="text-align:right">53 %</td> </tr>, <tr> <td>2012</td> <td style="font-weight: bold; text-align:right">7,125,828,059</td> <td style="text-align:right">1.20 %</td> <td style="text-align:right">84,633,758</td> <td style="text-align:right">48</td> <td style="text-align:right">3,747,842,586</td> <td style="text-align:right">53 %</td> </tr>]

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>-5000</td>, <td style="font-weight: bold; text-align:right">5,000,000</td>, <td style="text-align:right"> </td>, <td style="text-align:right"> </td>, <td style="text-align:right"> </td>, <td style="text-align:right"> </td>, <td style="text-align:right"> </td>]
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [-5000, 5,000,000,  ,  ,  ,  ,  ]

# %%
# reguler expression module helps to extract useful info from our tags code. 
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [-5000, 5,000,000,  ,  ,  ,  ,  ]
# str

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1  [2020, 7,794,798,739, 1.05 %, 81,330,639, 52, ...
# 2  [2019, 7,713,468,100, 1.08 %, 82,377,060, 52, ...
# 3  [2018, 7,631,091,040, 1.10 %, 83,232,115, 51, ...
# 4  [2017, 7,547,858,925, 1.12 %, 83,836,876, 51, ...
# 5  [2016, 7,464,022,049, 1.14 %, 84,224,910, 50, ...
# 6  [2015, 7,379,797,139, 1.16 %, 84,506,374, 50, ...
# 7  [2014, 7,295,290,765, 1.17 %, 84,708,789, 49, ...
# 8  [2013, 7,210,581,976, 1.19 %, 84,753,917, 48, ...
# 9  [2012, 7,125,828,059, 1.20 %, 84,633,758, 48, ...

# %% [markdown]
# <h4> Data manipulation and cleaning using Python's Pandas library

# %%
# now, we can split our messy table into column format
df1 = df[0].str.split(', ', expand=True)
df1.head(10)
# Out:
#        0              1       2           3     4              5      6
# 0     []           None    None        None  None           None   None
# 1  [2020  7,794,798,739  1.05 %  81,330,639    52  4,378,993,944  56 %]
# 2  [2019  7,713,468,100  1.08 %  82,377,060    52  4,299,438,618  56 %]
# 3  [2018  7,631,091,040  1.10 %  83,232,115    51  4,219,817,318  55 %]
# 4  [2017  7,547,858,925  1.12 %  83,836,876    51  4,140,188,594  55 %]
# 5  [2016  7,464,022,049  1.14 %  84,224,910    50  4,060,652,683  54 %]
# 6  [2015  7,379,797,139  1.16 %  84,506,374    50  3,981,497,663  54 %]
# 7  [2014  7,295,290,765  1.17 %  84,708,789    49  3,902,831,934  53 %]
# 8  [2013  7,210,581,976  1.19 %  84,753,917    48  3,824,990,329  53 %]
# 9  [2012  7,125,828,059  1.20 %  84,633,758    48  3,747,842,586  53 %]

# %%
col_labels = soup.find_all('th')

# %%
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#       0              1       2           3     4              5      6
# 0     ]           None    None        None  None           None   None
# 1  2020  7,794,798,739  1.05 %  81,330,639    52  4,378,993,944  56 %]
# 2  2019  7,713,468,100  1.08 %  82,377,060    52  4,299,438,618  56 %]
# 3  2018  7,631,091,040  1.10 %  83,232,115    51  4,219,817,318  55 %]
# 4  2017  7,547,858,925  1.12 %  83,836,876    51  4,140,188,594  55 %]
# 5  2016  7,464,022,049  1.14 %  84,224,910    50  4,060,652,683  54 %]
# 6  2015  7,379,797,139  1.16 %  84,506,374    50  3,981,497,663  54 %]
# 7  2014  7,295,290,765  1.17 %  84,708,789    49  3,902,831,934  53 %]
# 8  2013  7,210,581,976  1.19 %  84,753,917    48  3,824,990,329  53 %]
# 9  2012  7,125,828,059  1.20 %  84,633,758    48  3,747,842,586  53 %]

# %%
# we will clean our table heading and to summrised our data in perticuler column
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Year, World Population, YearlyChange, NetChange, Density(P/Km²), UrbanPop, UrbanPop %]']

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Year, World Population, YearlyChange, NetChan...

# %%
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#        0                  1              2           3                4  \
# 0  [Year   World Population   YearlyChange   NetChange   Density(P/Km²)
#
#            5             6
# 0   UrbanPop   UrbanPop %]

# %%
frames = [df3, df1]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#        0                  1              2           3                4  \
# 0  [Year   World Population   YearlyChange   NetChange   Density(P/Km²)
# 0      ]               None           None        None             None
# 1   2020      7,794,798,739         1.05 %  81,330,639               52
# 2   2019      7,713,468,100         1.08 %  82,377,060               52
# 3   2018      7,631,091,040         1.10 %  83,232,115               51
# 4   2017      7,547,858,925         1.12 %  83,836,876               51
# 5   2016      7,464,022,049         1.14 %  84,224,910               50
# 6   2015      7,379,797,139         1.16 %  84,506,374               50
# 7   2014      7,295,290,765         1.17 %  84,708,789               49
# 8   2013      7,210,581,976         1.19 %  84,753,917               48
#
#                5             6
# 0       UrbanPop   UrbanPop %]
# 0           None          None
# 1  4,378,993,944         56 %]
# 2  4,299,438,618         56 %]
# 3  4,219,817,318         55 %]
# 4  4,140,188,594         55 %]
# 5  4,060,652,683         54 %]
# 6  3,981,497,663         54 %]
# 7  3,902,831,934         53 %]
# 8  3,824,990,329         53 %]

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#    [Year   World Population   YearlyChange   NetChange   Density(P/Km²)  \
# 0  [Year   World Population   YearlyChange   NetChange   Density(P/Km²)
# 0      ]               None           None        None             None
# 1   2020      7,794,798,739         1.05 %  81,330,639               52
# 2   2019      7,713,468,100         1.08 %  82,377,060               52
# 3   2018      7,631,091,040         1.10 %  83,232,115               51
#
#         UrbanPop   UrbanPop %]
# 0       UrbanPop   UrbanPop %]
# 0           None          None
# 1  4,378,993,944         56 %]
# 2  4,299,438,618         56 %]
# 3  4,219,817,318         55 %]

# %%
df5.rename(columns={'[Year': 'Year'},inplace=True)
df5.rename(columns={'UrbanPop %]': 'urbanPop'},inplace=True)
df5.head()
# Out:
#     Year   World Population   YearlyChange   NetChange   Density(P/Km²)  \
# 0  [Year   World Population   YearlyChange   NetChange   Density(P/Km²)
# 0      ]               None           None        None             None
# 1   2020      7,794,798,739         1.05 %  81,330,639               52
# 2   2019      7,713,468,100         1.08 %  82,377,060               52
# 3   2018      7,631,091,040         1.10 %  83,232,115               51
#
#         UrbanPop   UrbanPop %]
# 0       UrbanPop   UrbanPop %]
# 0           None          None
# 1  4,378,993,944         56 %]
# 2  4,299,438,618         56 %]
# 3  4,219,817,318         55 %]

# %%
df5.head(10)
# Out:
#     Year   World Population   YearlyChange   NetChange   Density(P/Km²)  \
# 0  [Year   World Population   YearlyChange   NetChange   Density(P/Km²)
# 0      ]               None           None        None             None
# 1   2020      7,794,798,739         1.05 %  81,330,639               52
# 2   2019      7,713,468,100         1.08 %  82,377,060               52
# 3   2018      7,631,091,040         1.10 %  83,232,115               51
# 4   2017      7,547,858,925         1.12 %  83,836,876               51
# 5   2016      7,464,022,049         1.14 %  84,224,910               50
# 6   2015      7,379,797,139         1.16 %  84,506,374               50
# 7   2014      7,295,290,765         1.17 %  84,708,789               49
# 8   2013      7,210,581,976         1.19 %  84,753,917               48
#
#         UrbanPop   UrbanPop %]
# 0       UrbanPop   UrbanPop %]
# 0           None          None
# 1  4,378,993,944         56 %]
# 2  4,299,438,618         56 %]
# 3  4,219,817,318         55 %]
# 4  4,140,188,594         55 %]
# 5  4,060,652,683         54 %]
# 6  3,981,497,663         54 %]
# 7  3,902,831,934         53 %]
# 8  3,824,990,329         53 %]

# %%
df6 = df5.drop(df5.index[0])
df6.head()
# Out:
#    Year  World Population  YearlyChange   NetChange  Density(P/Km²)  \
# 1  2020     7,794,798,739        1.05 %  81,330,639              52
# 2  2019     7,713,468,100        1.08 %  82,377,060              52
# 3  2018     7,631,091,040        1.10 %  83,232,115              51
# 4  2017     7,547,858,925        1.12 %  83,836,876              51
# 5  2016     7,464,022,049        1.14 %  84,224,910              50
#
#         UrbanPop  UrbanPop %]
# 1  4,378,993,944        56 %]
# 2  4,299,438,618        56 %]
# 3  4,219,817,318        55 %]
# 4  4,140,188,594        55 %]
# 5  4,060,652,683        54 %]

# %%
# so, the last step is to save our dataframe in csv or excel file.
df6.to_excel('G:\world_pop_year.xlsx')

# %% [markdown]
# we got our file

# %%
world_pop = pd.read_excel('world_pop_year.xlsx')
world_pop.head()
# Out:
#    Unnamed: 0  Year  World Population  YearlyChange   NetChange  \
# 0           1  2020     7,794,798,739        1.05 %  81,330,639
# 1           2  2019     7,713,468,100        1.08 %  82,377,060
# 2           3  2018     7,631,091,040        1.10 %  83,232,115
# 3           4  2017     7,547,858,925        1.12 %  83,836,876
# 4           5  2016     7,464,022,049        1.14 %  84,224,910
#
#    Density(P/Km²)       UrbanPop  UrbanPop %]
# 0              52  4,378,993,944        56 %]
# 1              52  4,299,438,618        56 %]
# 2              51  4,219,817,318        55 %]
# 3              51  4,140,188,594        55 %]
# 4              50  4,060,652,683        54 %]

# %% [markdown]
# <h5> ----------------------------MISSION ACCOMPLISHED--------------------------------------
